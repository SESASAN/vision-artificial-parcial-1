# %% [markdown]
# # Preparación: imagen generada con IA
#
# Genera una imagen con un generador de IA gratuito (ej. Bing Image Creator). Usa tu creatividad para generar la imagen que prefieras.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

import sys
sys.path.append("..")

# %% [markdown]
# ## Prompt e imagen usada
#
# Incorpora aquí el texto (prompt) usado para generar la imagen.

# %%
# TODO: guardar la imagen generada en ../images/mi_imagen.png
img_path = "../images/mi_imagen.png"
img = np.array(Image.open(img_path).convert("RGB"))
print(img.shape, img.dtype)
plt.imshow(img)
plt.axis("off")
# Out:
# (832, 1248, 3) uint8
# (np.float64(-0.5), np.float64(1247.5), np.float64(831.5), np.float64(-0.5))
