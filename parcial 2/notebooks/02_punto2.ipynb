# %% [markdown]
# # Punto 2 (0.6) — Especificación de histograma
#
# Aplique correctamente la especificación del histograma sobre su imagen en escala de grises, tomando como referencia/objetivo la imagen "Referencia.tif" (adjunta). Complete la tabla.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from skimage.exposure import match_histograms

import sys
sys.path.append("..")

# %% [markdown]
# ## Imagen de referencia en escala de gris

# %%
ref = np.array(Image.open("../images/Referencia.tif").convert("L"))
plt.imshow(ref, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(499.5), np.float64(-0.5))

# %% [markdown]
# ## Histograma de la imagen de referencia

# %%
hist_ref = cv2.calcHist([ref], [0], None, [256], [0, 256]).flatten()

plt.figure()
plt.plot(hist_ref)
plt.xlabel("Nivel de intensidad")
plt.ylabel("Numero de pixeles")
plt.savefig("../results/punto2_histograma_referencia.png", bbox_inches="tight")

# %% [markdown]
# ## Especificación del histograma
#
# Realice la especificación del histograma sobre la imagen en escala de gris original y usando como referencia la imagen adjunta.

# %%
img = np.array(Image.open("../images/mi_imagen.png").convert("RGB"))
gray = np.array(Image.fromarray(img).convert("L"))

gray_spec = match_histograms(gray, ref).astype(np.uint8)

plt.imshow(gray_spec, cmap="gray")
plt.axis("off")
plt.savefig("../results/punto2_especificacion.png", bbox_inches="tight", pad_inches=0)

# %% [markdown]
# ## Histograma de la imagen resultante de la especificación

# %%
hist_spec = cv2.calcHist([gray_spec], [0], None, [256], [0, 256]).flatten()

plt.figure()
plt.plot(hist_spec)
plt.xlabel("Nivel de intensidad")
plt.ylabel("Numero de pixeles")
plt.savefig("../results/punto2_histograma_especificacion.png", bbox_inches="tight")
