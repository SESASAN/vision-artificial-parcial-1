# %% [markdown]
# # Punto 5 (0.6) — Realce de bordes (Laplaciano)
#
# Aplique a su imagen los filtros de realce de bordes Laplacianos de 4 y 8 vecinos vistos en clase. Recuerde que son diferentes a los filtros de detección de bordes del Punto 4.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

import sys
sys.path.append("..")

# %% [markdown]
# ## Realce con Laplaciano de 4 vecinos
#
# Incorpore aquí la imagen resultante tras aplicar el realce de bordes con el Laplaciano de 4 vecinos.

# %%
# TODO: cargar gray (imagen original en escala de grises, ver Punto 1)
gray = None

# TODO: definir el kernel de realce con Laplaciano de 4 vecinos (visto en clase)
# y aplicarlo sobre gray
realce_4 = None

# %% [markdown]
# ## Realce con Laplaciano de 8 vecinos
#
# Incorpore aquí la imagen resultante tras aplicar el realce de bordes con el Laplaciano de 8 vecinos.

# %%
# TODO: definir el kernel de realce con Laplaciano de 8 vecinos (visto en clase)
# y aplicarlo sobre gray
realce_8 = None
